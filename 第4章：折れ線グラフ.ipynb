# %%
import matplotlib.pyplot as plt
import numpy as np
import math


domain = np.arange(-10, 10.1, 0.1)
domain = np.round(domain, 1)
X = [float(x) for x in domain]
Y = [math.exp(x) for x in domain]


plt.plot(X, Y)
plt.show()
