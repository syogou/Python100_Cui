# %%
import random
import matplotlib.pyplot as plt

X = ["X{}".format(x) for x in range(10)]
Y = [5 * random.random() for _ in range(10)]

X, Y
# Out:
# (['X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9'],
#  [1.2282574663550778,
#   3.7920962624282155,
#   4.364973716176706,
#   1.707498468503783,
#   1.1135184957503759,
#   1.3908020381511261,
#   0.3315410665038998,
#   1.447368980921231,
#   4.938333822024154,
#   4.417063251648952])

# %%
XY = []
for x, y in zip(X, Y):
    XY.append([x, y])

XY
# Out:
# [['X0', 1.2282574663550778],
#  ['X1', 3.7920962624282155],
#  ['X2', 4.364973716176706],
#  ['X3', 1.707498468503783],
#  ['X4', 1.1135184957503759],
#  ['X5', 1.3908020381511261],
#  ['X6', 0.3315410665038998],
#  ['X7', 1.447368980921231],
#  ['X8', 4.938333822024154],
#  ['X9', 4.417063251648952]]

# %%
XY.sort(key=lambda x: x[1], reverse=False)
XY
# Out:
# [['X6', 0.3315410665038998],
#  ['X4', 1.1135184957503759],
#  ['X0', 1.2282574663550778],
#  ['X5', 1.3908020381511261],
#  ['X7', 1.447368980921231],
#  ['X3', 1.707498468503783],
#  ['X1', 3.7920962624282155],
#  ['X2', 4.364973716176706],
#  ['X9', 4.417063251648952],
#  ['X8', 4.938333822024154]]

# %%
plt.barh([xy[0] for xy in XY], [xy[1] for xy in XY])
plt.xlabel("Y")
plt.grid()
plt.show()
